# %% [markdown]
# ### 🏷️ **Credits & License**
#
# * 🔗 [OmniVoice GitHub Repository](https://github.com/k2-fsa/OmniVoice)
# * 🤗 [OmniVoice on Hugging Face](https://huggingface.co/k2-fsa/OmniVoice)
# * 📄 **License**: Provided under the [Apache License 2.0
# ](https://github.com/k2-fsa/OmniVoice/blob/master/LICENSE)
#
#
#
# ### ⚠️ **Usage Disclaimer**
#
# Use of this voice cloning model is subject to strict ethical and legal standards. By using this tool, you agree **not to** engage in any of the following prohibited activities:
#
# * **Fraud or Deception**: Using cloned voices to create misleading or fraudulent content.
# * **Impersonation**: Replicating someone’s voice without their explicit permission, especially for malicious, harmful, or deceptive purposes.
# * **Illegal Activities**: Employing the model in any manner that violates local, national, or international laws and regulations.
# * **Harmful Content Generation**: Creating offensive, defamatory, or unethical material, including content that spreads misinformation or causes harm.
#
# > ⚖️ **Legal Responsibility**
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
#@title Install OmniVoice
# %cd /content/
# !rm -rf ./omnivoice-colab
# !git clone https://github.com/NeuralFalconYT/omnivoice-colab.git
# %cd ./omnivoice-colab
# !git clone https://github.com/k2-fsa/OmniVoice.git
# !git clone https://github.com/NeuralFalconYT/OmniVoice.git
# !pip install -r colab.txt
# !pip install -r requirements.txt
from IPython.display import clear_output
clear_output()

# %%
#@title Run Gradio APP
# %cd /content/omnivoice-colab
# !python app.py
# Out:
# /content/omnivoice-colab
# Loading model from k2-fsa/OmniVoice to cuda ...
# config.json: 100% 2.24k/2.24k [00:00<00:00, 1.43MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-07-29 18:23:53,986 huggingface_hub.utils._http WARNING: Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# model.safetensors: downloading bytes:  10% 244M/2.45G [00:01<00:09, 242MB/s, 19.0MB/s  ]
# model.safetensors: reconstructing file:   3% 67.1M/2.45G [00:02<01:12, 33.0MB/s]
# model.safetensors: downloading bytes:  14% 343M/2.45G [00:02<00:08, 236MB/s, 30.2MB/s  ]
# model.safetensors: downloading bytes:  30% 744M/2.45G [00:03<00:07, 239MB/s, 61.7MB/s  ]
# model.safetensors: downloading bytes:  44% 1.08G/2.45G [00:05<00:06, 204MB/s, 80.3MB/s  ]
# model.safetensors: downloading bytes:  71% 1.74G/2.45G [00:07<00:01, 393MB/s,  116MB/s  ]
# model.safetensors: downloading bytes:  94% 2.29G/2.45G [00:09<00:00, 405MB/s,  146MB/s  ]
# model.safetensors: reconstructing file:  47% 1.14G/2.45G [00:12<00:14, 88.3MB/s, 54.5MB/s  ]
# model.safetensors: downloading bytes: 100% 2.32G/2.32G [00:20<00:00, 112MB/s,  149MB/s  ]
# model.safetensors: reconstructing file: 100% 2.45G/2.45G [00:20<00:00, 119MB/s,  132MB/s  ]
# Loading weights: 100% 313/313 [00:00<00:00, 335.51it/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/806M [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 0.00/806M [00:00<?, ?B/s]
# Downloading bytes:   0% 1.57k/806M [00:00<35:04:29, 6.38kB/s]
#
# Fetching 13 files:   8% 1/13 [00:00<00:02,  4.28it/s]
# Reconstructing (incomplete total...):   0% 1.57k/806M [00:00<35:00:59, 6.39kB/s]
# Reconstructing (incomplete total...):   0% 1.57k/806M [00:00<35:00:59, 6.39kB/s]
# Reconstructing (incomplete total...):   0% 3.09k/806M [00:00<35:00:59, 6.39kB/s]
# Reconstructing (incomplete total...):   0% 15.0k/817M [00:00<35:30:45, 6.39kB/s]
# Reconstructing (incomplete total...):   0% 15.0k/817M [00:00<35:30:46, 6.39kB/s]
# Reconstructing (incomplete total...):   0% 24.2k/817M [00:00<35:30:46, 6.39kB/s]
# Reconstructing (incomplete total...):   0% 29.4k/817M [00:00<35:30:45, 6.39kB/s]
# Reconstructing (incomplete total...):   0% 29.6k/817M [00:00<35:30:46, 6.39kB/s]
# Downloading bytes:   0% 33.8k/817M [00:00<2:48:07, 81.0kB/s]
# Reconstructing (incomplete total...):   0% 33.8k/817M [00:00<2:48:01, 81.1kB/s]
# Downloading bytes:   7% 57.9M/817M [00:01<00:13, 55.8MB/s, 1.48MB/s  ]
# Downloading bytes:  12% 98.0M/817M [00:01<00:07, 101MB/s, 5.59MB/s  ]
# Downloading bytes:  31% 252M/817M [00:02<00:02, 271MB/s, 19.7MB/s  ]
# Downloading bytes:  47% 388M/817M [00:02<00:01, 226MB/s, 33.4MB/s  ]
# Reconstructing (incomplete total...):  36% 298M/817M [00:02<00:02, 185MB/s, 12.5MB/s  ]
# Downloading bytes:  53% 429M/817M [00:02<00:01, 220MB/s, 35.5MB/s  ]
# Downloading bytes:  63% 511M/817M [00:03<00:01, 244MB/s, 41.7MB/s  ]
# Downloading bytes:  80% 657M/817M [00:03<00:00, 273MB/s, 52.9MB/s  ]
# Reconstructing (incomplete total...):  60% 487M/817M [00:04<00:03, 99.5MB/s, 34.7MB/s  ]
# Reconstructing (incomplete total...):  65% 534M/817M [00:04<00:02, 110MB/s, 37.9MB/s  ]
# Reconstructing (incomplete total...):  72% 591M/817M [00:09<00:07, 31.2MB/s, 41.1MB/s  ]
# Reconstructing (incomplete total...):  86% 702M/817M [00:09<00:02, 56.3MB/s, 31.9MB/s  ]
# Reconstructing (incomplete total...):  93% 756M/817M [00:10<00:00, 65.6MB/s, 40.8MB/s  ]
# Reconstructing (incomplete total...): 100% 817M/817M [00:13<00:00, 36.4MB/s, 43.9MB/s  ]
#
# Fetching 13 files: 100% 13/13 [00:13<00:00,  1.06s/it]
# Download complete: 100% 663M/663M [00:13<00:00, 273MB/s, 51.5MB/s  ]
# Download complete: 100% 663M/663M [00:15<00:00, 41.4MB/s, 51.5MB/s  ]
# Reconstruction complete: 100% 817M/817M [00:15<00:00, 51.1MB/s, 37.7MB/s  ]
# Loading weights: 100% 527/527 [00:00<00:00, 1585.96it/s]
# Model loaded successfully!
# /content/omnivoice-colab/app.py:325: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="OmniVoice Demo") as demo:
# /content/omnivoice-colab/app.py:325: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="OmniVoice Demo") as demo:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://ff90acbd08ffc37500.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# /content/omnivoice-colab/OmniVoice/omnivoice/utils/audio.py:63: UserWarning: PySoundFile failed. Trying audioread instead.
#   data, sr = librosa.load(audio_path, sr=None, mono=False)
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# 2026-07-29 18:31:14,948 omnivoice.models.omnivoice DEBUG: Item 0 chunked into 4 pieces: ['ज़रा सोचिए... अगर आपको अचानक ₹1180 करोड़ मिल जाएँ... लेकिन उन्हें सिर्फ़ 30 दिनों के अंदर पूरा खर्च करना पड़े... वरना आपको एक रुपया भी नहीं मिलेगा! \n\nयही नामुमकिन चैलेंज मिलता है हमारे हीरो, डुओ-यू,', 'को।\n\nलेकिन असली खेल तो अब शुरू होता है...\n\nवो न कोई घर या प्रॉपर्टी खरीद सकता है...\nन किसी को दान दे सकता है...\nऔर न ही किसी को बता सकता है कि उसके पास ₹1180 करोड़ हैं!', 'हमारा हीरो डुओ-यू जितना ज़्यादा ₹1180 करोड़ खर्च करने की कोशिश करता है... उतनी ही ज़्यादा मुसीबतें उसके सामने खड़ी होती जाती हैं।\n\nअब सवाल ये है... क्या डुओ-यू सिर्फ़ 30 दिनों में पूरे ₹1180 करोड़ खर्च कर पाया...', 'या एक छोटी-सी गलती ने उसे फिर से सड़क पर ला दिया?\n\nइस नामुमकिन चैलेंज का हैरान कर देने वाला अंत जानने के लिए नीचे दिए गए लिंक पर क्लिक करें और Agzotra पर अभी पूरी मूवी एक्सप्लेनेशन देखें!']
# 2026-07-29 18:31:14,948 omnivoice.models.omnivoice DEBUG: Item 0 — text: ज़रा सोचिए... अगर आपको अचानक ₹1180 करोड़ मिल जाएँ... लेकिन उन्हें सिर्फ़ 30 दिनों के अंदर पूरा खर्च करना पड़े... वरना आपको एक रुपया भी नहीं मिलेगा!
#
# यही नामुमकिन चैलेंज मिलता है हमारे हीरो, डुओ-यू, | ref_text: जी अंकल, जी अंकल, फिल्म फेर अबर्ड जो टीटी, हाँ जी बेस्ट अक्टर के लिए नॉमिनेट हुआ हूँ, हाँ मैं आपको लेंग भेजता हूँ, आप सबको बोलीगा, बोट करे, हाँ जी 10 नमेंबर लास्ट डेट है, हाँ, हाँ अंकल बाद में बाद करता हूँ, ह हाँ, हाँ माँ, अबाद में आरी. | instruct: None | lang: hi | target_tokens: 342
# 2026-07-29 18:31:23,125 omnivoice.models.omnivoice DEBUG: Item 0 — text: को।
#
# लेकिन असली खेल तो अब शुरू होता है...
#
# वो न कोई घर या प्रॉपर्टी खरीद सकता है...
# न किसी को दान दे सकता है...
# और न ही किसी को बता सकता है कि उसके पास ₹1180 करोड़ हैं! | ref_text: जी अंकल, जी अंकल, फिल्म फेर अबर्ड जो टीटी, हाँ जी बेस्ट अक्टर के लिए नॉमिनेट हुआ हूँ, हाँ मैं आपको लेंग भेजता हूँ, आप सबको बोलीगा, बोट करे, हाँ जी 10 नमेंबर लास्ट डेट है, हाँ, हाँ अंकल बाद में बाद करता हूँ, ह हाँ, हाँ माँ, अबाद में आरी. | instruct: None | lang: hi | target_tokens: 283
# 2026-07-29 18:31:30,357 omnivoice.models.omnivoice DEBUG: Item 0 — text: हमारा हीरो डुओ-यू जितना ज़्यादा ₹1180 करोड़ खर्च करने की कोशिश करता है... उतनी ही ज़्यादा मुसीबतें उसके सामने खड़ी होती जाती हैं।
#
# अब सवाल ये है... क्या डुओ-यू सिर्फ़ 30 दिनों में पूरे ₹1180 करोड़ खर्च कर पाया... | ref_text: जी अंकल, जी अंकल, फिल्म फेर अबर्ड जो टीटी, हाँ जी बेस्ट अक्टर के लिए नॉमिनेट हुआ हूँ, हाँ मैं आपको लेंग भेजता हूँ, आप सबको बोलीगा, बोट करे, हाँ जी 10 नमेंबर लास्ट डेट है, हाँ, हाँ अंकल बाद में बाद करता हूँ, ह हाँ, हाँ माँ, अबाद में आरी. | instruct: None | lang: hi | target_tokens: 365
# 2026-07-29 18:31:38,665 omnivoice.models.omnivoice DEBUG: Item 0 — text: या एक छोटी-सी गलती ने उसे फिर से सड़क पर ला दिया?
#
# इस नामुमकिन चैलेंज का हैरान कर देने वाला अंत जानने के लिए नीचे दिए गए लिंक पर क्लिक करें और Agzotra पर अभी पूरी मूवी एक्सप्लेनेशन देखें! | ref_text: जी अंकल, जी अंकल, फिल्म फेर अबर्ड जो टीटी, हाँ जी बेस्ट अक्टर के लिए नॉमिनेट हुआ हूँ, हाँ मैं आपको लेंग भेजता हूँ, आप सबको बोलीगा, बोट करे, हाँ जी 10 नमेंबर लास्ट डेट है, हाँ, हाँ अंकल बाद में बाद करता हूँ, ह हाँ, हाँ माँ, अबाद में आरी. | instruct: None | lang: hi | target_tokens: 308
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 3043, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/omnivoice-colab/app.py", line 493, in <module>
#     demo.queue().launch(share=True, debug=True)
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2950, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 3047, in block_thread
#     self.server.close()
#   File "/usr/local/lib/python3.12/dist-packages/gradio/http_server.py", line 69, in close
#     self.thread.join(timeout=5)
#   File "/usr/lib/python3.12/threading.py", line 1153, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/usr/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Killing tunnel 127.0.0.1:7860 <> https://ff90acbd08ffc37500.gradio.live
# ^C
